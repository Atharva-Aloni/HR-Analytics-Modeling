# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df = pd.read_excel('../DataSets/HR data.xlsx')

# %%
df
# Out:
#      Attrition    Business Travel CF_age band CF_attrition label Department  \
# 0          Yes      Travel_Rarely     35 - 44       Ex-Employees      Sales
# 1           No  Travel_Frequently     45 - 54  Current Employees        R&D
# 2          Yes      Travel_Rarely     35 - 44       Ex-Employees        R&D
# 3           No  Travel_Frequently     25 - 34  Current Employees        R&D
# 4           No      Travel_Rarely     25 - 34  Current Employees        R&D
# ...        ...                ...         ...                ...        ...
# 1465       Yes         Non-Travel     25 - 34       Ex-Employees        R&D
# 1466       Yes  Travel_Frequently     25 - 34       Ex-Employees        R&D
# 1467       Yes  Travel_Frequently     35 - 44       Ex-Employees      Sales
# 1468       Yes      Travel_Rarely    Under 25       Ex-Employees        R&D
# 1469       Yes      Travel_Rarely    Under 25       Ex-Employees      Sales
#
# ...

# %%
df.columns
# Out:
# Index([                 'Attrition',            'Business Travel',
#                       'CF_age band',         'CF_attrition label',
#                        'Department',            'Education Field',
#                            'emp no',            'Employee Number',
#                            'Gender',                   'Job Role',
#                    'Marital Status',                  'Over Time',
#                            'Over18',   'Training Times Last Year',
#                                   0,                        '0.1',
#                               'Age',        'CF_current Employee',
#                        'Daily Rate',         'Distance From Home',
#                         'Education',             'Employee Count',
#          'Environment Satisfaction',                'Hourly Rate',
#                   'Job Involvement',                  'Job Level',
#                  'Job Satisfaction',             'Monthly Income',
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 41 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Attrition                   1470 non-null   object
#  1   Business Travel             1470 non-null   object
#  2   CF_age band                 1470 non-null   object
#  3   CF_attrition label          1470 non-null   object
#  4   Department                  1470 non-null   object
#  5   Education Field             1470 non-null   object
#  6   emp no                      1470 non-null   object
#  7   Employee Number             1470 non-null   int64
#  8   Gender                      1470 non-null   object
#  9   Job Role                    1470 non-null   object
#  10  Marital Status              1470 non-null   object
#  11  Over Time                   1470 non-null   object
#  12  Over18                      1470 non-null   object
# ...

# %%
df.isna().sum()
# Out:
# Attrition                     0
# Business Travel               0
# CF_age band                   0
# CF_attrition label            0
# Department                    0
# Education Field               0
# emp no                        0
# Employee Number               0
# Gender                        0
# Job Role                      0
# Marital Status                0
# Over Time                     0
# Over18                        0
# Training Times Last Year      0
# 0                             0
# 0.1                           0
# Age                           0
# CF_current Employee           0
# Daily Rate                    0
# Distance From Home            0
# Education                     0
# Employee Count                0
# Environment Satisfaction      0
# Hourly Rate                   0
# Job Involvement               0
# Job Level                     0
# Job Satisfaction              0
# Monthly Income                0
# Monthly Rate                  0
# ...

# %%
df.dtypes
# Out:
# Attrition                     object
# Business Travel               object
# CF_age band                   object
# CF_attrition label            object
# Department                    object
# Education Field               object
# emp no                        object
# Employee Number                int64
# Gender                        object
# Job Role                      object
# Marital Status                object
# Over Time                     object
# Over18                        object
# Training Times Last Year       int64
# 0                              int64
# 0.1                            int64
# Age                            int64
# CF_current Employee            int64
# Daily Rate                     int64
# Distance From Home             int64
# Education                     object
# Employee Count                 int64
# Environment Satisfaction       int64
# Hourly Rate                    int64
# Job Involvement                int64
# ...

# %%
df.head(10)
# Out:
#   Attrition    Business Travel CF_age band CF_attrition label Department  \
# 0       Yes      Travel_Rarely     35 - 44       Ex-Employees      Sales
# 1        No  Travel_Frequently     45 - 54  Current Employees        R&D
# 2       Yes      Travel_Rarely     35 - 44       Ex-Employees        R&D
# 3        No  Travel_Frequently     25 - 34  Current Employees        R&D
# 4        No      Travel_Rarely     25 - 34  Current Employees        R&D
# 5        No  Travel_Frequently     25 - 34  Current Employees        R&D
# 6        No      Travel_Rarely     Over 55  Current Employees        R&D
# 7        No      Travel_Rarely     25 - 34  Current Employees        R&D
# 8        No  Travel_Frequently     35 - 44  Current Employees        R&D
# 9        No      Travel_Rarely     35 - 44  Current Employees        R&D
#
#   Education Field    emp no  Employee Number  Gender  \
# 0   Life Sciences   STAFF-1                1  Female
# 1   Life Sciences   STAFF-2                2    Male
# ...

# %%
df.tail(10)
# Out:
#      Attrition    Business Travel CF_age band CF_attrition label Department  \
# 1460       Yes      Travel_Rarely     45 - 54       Ex-Employees      Sales
# 1461       Yes  Travel_Frequently     45 - 54       Ex-Employees        R&D
# 1462       Yes         Non-Travel     35 - 44       Ex-Employees        R&D
# 1463       Yes      Travel_Rarely     25 - 34       Ex-Employees      Sales
# 1464       Yes      Travel_Rarely     25 - 34       Ex-Employees      Sales
# 1465       Yes         Non-Travel     25 - 34       Ex-Employees        R&D
# 1466       Yes  Travel_Frequently     25 - 34       Ex-Employees        R&D
# 1467       Yes  Travel_Frequently     35 - 44       Ex-Employees      Sales
# 1468       Yes      Travel_Rarely    Under 25       Ex-Employees        R&D
# 1469       Yes      Travel_Rarely    Under 25       Ex-Employees      Sales
#
#        Education Field      emp no  Employee Number  Gender  \
# 1460     Life Sciences  STAFF-1869             1869  Female
# ...

# %%
df.describe()
# Out:
#        Employee Number  Training Times Last Year       0     0.1          Age  \
# count      1470.000000               1470.000000  1470.0  1470.0  1470.000000
# mean       1024.865306                  2.799320    -2.0     0.0    36.923810
# std         602.024335                  1.289271     0.0     0.0     9.135373
# min           1.000000                  0.000000    -2.0     0.0    18.000000
# 25%         491.250000                  2.000000    -2.0     0.0    30.000000
# 50%        1020.500000                  3.000000    -2.0     0.0    36.000000
# 75%        1555.750000                  3.000000    -2.0     0.0    43.000000
# max        2068.000000                  6.000000    -2.0     0.0    60.000000
#
#        CF_current Employee   Daily Rate  Distance From Home  Employee Count  \
# count          1470.000000  1470.000000         1470.000000          1470.0
# mean              0.838776   802.485714            9.192517             1.0
# ...

# %%
df.columns
# Out:
# Index([                 'Attrition',            'Business Travel',
#                       'CF_age band',         'CF_attrition label',
#                        'Department',            'Education Field',
#                            'emp no',            'Employee Number',
#                            'Gender',                   'Job Role',
#                    'Marital Status',                  'Over Time',
#                            'Over18',   'Training Times Last Year',
#                                   0,                        '0.1',
#                               'Age',        'CF_current Employee',
#                        'Daily Rate',         'Distance From Home',
#                         'Education',             'Employee Count',
#          'Environment Satisfaction',                'Hourly Rate',
#                   'Job Involvement',                  'Job Level',
#                  'Job Satisfaction',             'Monthly Income',
# ...

# %%
df = df.rename(columns={'CF_age band':'CF_age_band','emp no':'emp_no','Marital Status':'Marital_Status','Daily Rate':'Daily_Rate','Environment Satisfaction':'Environment_Satisfaction'})

# %%
df
# Out:
#      Attrition    Business Travel CF_age_band CF_attrition label Department  \
# 0          Yes      Travel_Rarely     35 - 44       Ex-Employees      Sales
# 1           No  Travel_Frequently     45 - 54  Current Employees        R&D
# 2          Yes      Travel_Rarely     35 - 44       Ex-Employees        R&D
# 3           No  Travel_Frequently     25 - 34  Current Employees        R&D
# 4           No      Travel_Rarely     25 - 34  Current Employees        R&D
# ...        ...                ...         ...                ...        ...
# 1465       Yes         Non-Travel     25 - 34       Ex-Employees        R&D
# 1466       Yes  Travel_Frequently     25 - 34       Ex-Employees        R&D
# 1467       Yes  Travel_Frequently     35 - 44       Ex-Employees      Sales
# 1468       Yes      Travel_Rarely    Under 25       Ex-Employees        R&D
# 1469       Yes      Travel_Rarely    Under 25       Ex-Employees      Sales
#
# ...

# %%
df.columns
# Out:
# Index([                 'Attrition',            'Business Travel',
#                       'CF_age_band',         'CF_attrition label',
#                        'Department',            'Education Field',
#                            'emp_no',            'Employee Number',
#                            'Gender',                   'Job Role',
#                    'Marital_Status',                  'Over Time',
#                            'Over18',   'Training Times Last Year',
#                                   0,                        '0.1',
#                               'Age',        'CF_current Employee',
#                        'Daily_Rate',         'Distance From Home',
#                         'Education',             'Employee Count',
#          'Environment_Satisfaction',                'Hourly Rate',
#                   'Job Involvement',                  'Job Level',
#                  'Job Satisfaction',             'Monthly Income',
# ...

# %%
df[['Over18',0]].reset_index()
# Out:
#       index Over18  0
# 0         0      Y -2
# 1         1      Y -2
# 2         2      Y -2
# 3         3      Y -2
# 4         4      Y -2
# ...     ...    ... ..
# 1465   1465      Y -2
# 1466   1466      Y -2
# 1467   1467      Y -2
# 1468   1468      Y -2
# 1469   1469      Y -2
#
# [1470 rows x 3 columns]

# %%
df=df.drop(columns=[0])

# %%
df
# Out:
#      Attrition    Business Travel CF_age_band CF_attrition label Department  \
# 0          Yes      Travel_Rarely     35 - 44       Ex-Employees      Sales
# 1           No  Travel_Frequently     45 - 54  Current Employees        R&D
# 2          Yes      Travel_Rarely     35 - 44       Ex-Employees        R&D
# 3           No  Travel_Frequently     25 - 34  Current Employees        R&D
# 4           No      Travel_Rarely     25 - 34  Current Employees        R&D
# ...        ...                ...         ...                ...        ...
# 1465       Yes         Non-Travel     25 - 34       Ex-Employees        R&D
# 1466       Yes  Travel_Frequently     25 - 34       Ex-Employees        R&D
# 1467       Yes  Travel_Frequently     35 - 44       Ex-Employees      Sales
# 1468       Yes      Travel_Rarely    Under 25       Ex-Employees        R&D
# 1469       Yes      Travel_Rarely    Under 25       Ex-Employees      Sales
#
# ...

# %%
df.columns
# Out:
# Index(['Attrition', 'Business Travel', 'CF_age_band', 'CF_attrition label',
#        'Department', 'Education Field', 'emp_no', 'Employee Number', 'Gender',
#        'Job Role', 'Marital_Status', 'Over Time', 'Over18',
#        'Training Times Last Year', '0.1', 'Age', 'CF_current Employee',
#        'Daily_Rate', 'Distance From Home', 'Education', 'Employee Count',
#        'Environment_Satisfaction', 'Hourly Rate', 'Job Involvement',
#        'Job Level', 'Job Satisfaction', 'Monthly Income', 'Monthly Rate',
#        'Num Companies Worked', 'Percent Salary Hike', 'Performance Rating',
#        'Relationship Satisfaction', 'Standard Hours', 'Stock Option Level',
#        'Total Working Years', 'Work Life Balance', 'Years At Company',
#        'Years In Current Role', 'Years Since Last Promotion',
#        'Years With Curr Manager'],
#       dtype='object')

# %%
df=df.drop(columns='0.1')

# %%
df
# Out:
#      Attrition    Business Travel CF_age_band CF_attrition label Department  \
# 0          Yes      Travel_Rarely     35 - 44       Ex-Employees      Sales
# 1           No  Travel_Frequently     45 - 54  Current Employees        R&D
# 2          Yes      Travel_Rarely     35 - 44       Ex-Employees        R&D
# 3           No  Travel_Frequently     25 - 34  Current Employees        R&D
# 4           No      Travel_Rarely     25 - 34  Current Employees        R&D
# ...        ...                ...         ...                ...        ...
# 1465       Yes         Non-Travel     25 - 34       Ex-Employees        R&D
# 1466       Yes  Travel_Frequently     25 - 34       Ex-Employees        R&D
# 1467       Yes  Travel_Frequently     35 - 44       Ex-Employees      Sales
# 1468       Yes      Travel_Rarely    Under 25       Ex-Employees        R&D
# 1469       Yes      Travel_Rarely    Under 25       Ex-Employees      Sales
#
# ...

# %%
df.columns
# Out:
# Index(['Attrition', 'Business Travel', 'CF_age_band', 'CF_attrition label',
#        'Department', 'Education Field', 'emp_no', 'Employee Number', 'Gender',
#        'Job Role', 'Marital_Status', 'Over Time', 'Over18',
#        'Training Times Last Year', 'Age', 'CF_current Employee', 'Daily_Rate',
#        'Distance From Home', 'Education', 'Employee Count',
#        'Environment_Satisfaction', 'Hourly Rate', 'Job Involvement',
#        'Job Level', 'Job Satisfaction', 'Monthly Income', 'Monthly Rate',
#        'Num Companies Worked', 'Percent Salary Hike', 'Performance Rating',
#        'Relationship Satisfaction', 'Standard Hours', 'Stock Option Level',
#        'Total Working Years', 'Work Life Balance', 'Years At Company',
#        'Years In Current Role', 'Years Since Last Promotion',
#        'Years With Curr Manager'],
#       dtype='object')

# %%
df['Gender']=df['Gender'].replace({'Female':0,'Male':1}).astype('int64')
# Out:
# C:\Users\91788\AppData\Local\Temp\ipykernel_14492\3608755968.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Gender']=df['Gender'].replace({'Female':0,'Male':1}).astype('int64')

# %%
df['Gender']
# Out:
# 0       0
# 1       1
# 2       1
# 3       0
# 4       1
#        ..
# 1465    1
# 1466    1
# 1467    1
# 1468    1
# 1469    1
# Name: Gender, Length: 1470, dtype: int64

# %%
df.groupby('Gender').size()
# Out:
# Gender
# 0    588
# 1    882
# dtype: int64

# %%
df.groupby(['Department','Gender']).size()
# Out:
# Department  Gender
# HR          0          20
#             1          43
# R&D         0         379
#             1         582
# Sales       0         189
#             1         257
# dtype: int64

# %%
num_col = df.select_dtypes(include=['number'])

# %%
num_col
# Out:
#       Employee Number  Gender  Training Times Last Year  Age  \
# 0                   1       0                         0   41
# 1                   2       1                         3   49
# 2                   4       1                         3   37
# 3                   5       0                         3   33
# 4                   7       1                         3   27
# ...               ...     ...                       ...  ...
# 1465             1905       1                         2   34
# 1466             1868       1                         3   29
# 1467             1667       1                         2   35
# 1468             1878       1                         2   22
# 1469             1702       1                         2   23
#
#       CF_current Employee  Daily_Rate  Distance From Home  Employee Count  \
# 0                       0        1102                   1               1
# 1                       1         279                   8               1
# ...

# %%
corr = num_col.corr()

# %%
corr
# Out:
#                             Employee Number    Gender  \
# Employee Number                    1.000000  0.022556
# Gender                             0.022556  1.000000
# Training Times Last Year           0.023603 -0.038787
# Age                               -0.010145 -0.036311
# CF_current Employee                0.010577 -0.029453
# Daily_Rate                        -0.050990 -0.011716
# Distance From Home                 0.032916 -0.001851
# Employee Count                          NaN       NaN
# Environment_Satisfaction           0.017621  0.000508
# Hourly Rate                        0.035179 -0.000478
# Job Involvement                   -0.006888  0.017960
# Job Level                         -0.018519 -0.039403
# Job Satisfaction                  -0.046247  0.033252
# Monthly Income                    -0.014829 -0.031858
# Monthly Rate                       0.012648 -0.041482
# Num Companies Worked              -0.001251 -0.039147
# ...

# %%
sb.heatmap(corr,cbar=True,annot=True,cmap='Blues')
# Out:
# <Axes: >

# %%
df
# Out:
#      Attrition    Business Travel CF_age_band CF_attrition label Department  \
# 0          Yes      Travel_Rarely     35 - 44       Ex-Employees      Sales
# 1           No  Travel_Frequently     45 - 54  Current Employees        R&D
# 2          Yes      Travel_Rarely     35 - 44       Ex-Employees        R&D
# 3           No  Travel_Frequently     25 - 34  Current Employees        R&D
# 4           No      Travel_Rarely     25 - 34  Current Employees        R&D
# ...        ...                ...         ...                ...        ...
# 1465       Yes         Non-Travel     25 - 34       Ex-Employees        R&D
# 1466       Yes  Travel_Frequently     25 - 34       Ex-Employees        R&D
# 1467       Yes  Travel_Frequently     35 - 44       Ex-Employees      Sales
# 1468       Yes      Travel_Rarely    Under 25       Ex-Employees        R&D
# 1469       Yes      Travel_Rarely    Under 25       Ex-Employees      Sales
#
# ...

# %%
sb.barplot(x=df['Job Role'],y=df['Total Working Years'])
plt.xticks(rotation=90)
plt.show()

# %%
df.groupby('Department').count()
# Out:
#             Attrition  Business Travel  CF_age_band  CF_attrition label  \
# Department
# HR                 63               63           63                  63
# R&D               961              961          961                 961
# Sales             446              446          446                 446
#
#             Education Field  emp_no  Employee Number  Gender  Job Role  \
# Department
# HR                       63      63               63      63        63
# R&D                     961     961              961     961       961
# Sales                   446     446              446     446       446
#
#             Marital_Status  ...  Performance Rating  \
# Department                  ...
# HR                      63  ...                  63
# R&D                    961  ...                 961
# Sales                  446  ...                 446
#
#             Relationship Satisfaction  Standard Hours  Stock Option Level  \
# Department
# ...

# %%
df.groupby('Department')['Employee Number'].count()
# Out:
# Department
# HR        63
# R&D      961
# Sales    446
# Name: Employee Number, dtype: int64

# %%
df.groupby('Department')['Total Working Years'].mean()
# Out:
# Department
# HR       11.555556
# R&D      11.342352
# Sales    11.105381
# Name: Total Working Years, dtype: float64

# %%
df[df['Department']=='HR']['Total Working Years'].mean()
# Out:
# 11.555555555555555

# %%
graph1=df.groupby(['Department','Education Field'])['Total Working Years'].mean().reset_index()

# %%
graph1
# Out:
#    Department   Education Field  Total Working Years
# 0          HR   Human Resources            11.592593
# 1          HR     Life Sciences            13.125000
# 2          HR           Medical            12.000000
# 3          HR             Other            12.000000
# 4          HR  Technical Degree             3.250000
# 5         R&D     Life Sciences            11.059091
# 6         R&D           Medical            11.906336
# 7         R&D             Other            10.750000
# 8         R&D  Technical Degree            10.893617
# 9       Sales     Life Sciences            11.593333
# 10      Sales         Marketing            11.855346
# 11      Sales           Medical            10.090909
# 12      Sales             Other             8.333333
# 13      Sales  Technical Degree             9.294118

# %%
sb.barplot(x=graph1['Department'],y=graph1['Total Working Years'])
plt.xticks(rotation = 90)
plt.ylabel('Avg Years')
plt.show()

# %%
df
# Out:
#      Attrition    Business Travel CF_age_band CF_attrition label Department  \
# 0          Yes      Travel_Rarely     35 - 44       Ex-Employees      Sales
# 1           No  Travel_Frequently     45 - 54  Current Employees        R&D
# 2          Yes      Travel_Rarely     35 - 44       Ex-Employees        R&D
# 3           No  Travel_Frequently     25 - 34  Current Employees        R&D
# 4           No      Travel_Rarely     25 - 34  Current Employees        R&D
# ...        ...                ...         ...                ...        ...
# 1465       Yes         Non-Travel     25 - 34       Ex-Employees        R&D
# 1466       Yes  Travel_Frequently     25 - 34       Ex-Employees        R&D
# 1467       Yes  Travel_Frequently     35 - 44       Ex-Employees      Sales
# 1468       Yes      Travel_Rarely    Under 25       Ex-Employees        R&D
# 1469       Yes      Travel_Rarely    Under 25       Ex-Employees      Sales
#
# ...

# %%
data=df.groupby(['Department','Education Field','Gender'])['Attrition'].size().reset_index()

# %%
data
# Out:
#    Department   Education Field  Gender  Attrition
# 0          HR   Human Resources       0          8
# 1          HR   Human Resources       1         19
# 2          HR     Life Sciences       0          9
# 3          HR     Life Sciences       1          7
# 4          HR           Medical       0          2
# 5          HR           Medical       1         11
# 6          HR             Other       1          3
# 7          HR  Technical Degree       0          1
# 8          HR  Technical Degree       1          3
# 9         R&D     Life Sciences       0        166
# 10        R&D     Life Sciences       1        274
# 11        R&D           Medical       0        152
# 12        R&D           Medical       1        211
# 13        R&D             Other       0         25
# 14        R&D             Other       1         39
# 15        R&D  Technical Degree       0         36
# 16        R&D  Technical Degree       1         58
# ...

# %%
print(df['Department'].unique())
a = input("Enter the department to fetch attrition details = ")
da = df[df['Department']==a]
da
print(da['Education Field'].unique())
b = input(f"Enter the education for the {a} Department = ")
db = da[da['Education Field']==b]
v = len(db)
dr = db[(db['Attrition']=='Yes')]
dx = dr[dr['Gender']==1]
male = len(dx)
dr = db[(db['Attrition']=='Yes')]
dx = dr[dr['Gender']==0]
female = len(dx)
print(f"Attrition Rate of Males in {a} of {b} = {(male/v)*100}")
print(f"Attrition Rate of Female in {a} of {b} = {(female/v)*100}")
fig = plt.figure(figsize=[15,6])
# Out:
# ['Sales' 'R&D' 'HR']
# Enter the department to fetch attrition details =  HR
# ['Medical' 'Human Resources' 'Life Sciences' 'Technical Degree' 'Other']
# Enter the education for the HR Department =  Other
# Attrition Rate of Males in HR of Other = 0.0
# Attrition Rate of Female in HR of Other = 0.0

# %%
# Out:
#      Attrition    Business Travel CF_age_band CF_attrition label Department  \
# 1           No  Travel_Frequently     45 - 54  Current Employees        R&D
# 2          Yes      Travel_Rarely     35 - 44       Ex-Employees        R&D
# 3           No  Travel_Frequently     25 - 34  Current Employees        R&D
# 4           No      Travel_Rarely     25 - 34  Current Employees        R&D
# 5           No  Travel_Frequently     25 - 34  Current Employees        R&D
# ...        ...                ...         ...                ...        ...
# 1461       Yes  Travel_Frequently     45 - 54       Ex-Employees        R&D
# 1462       Yes         Non-Travel     35 - 44       Ex-Employees        R&D
# 1465       Yes         Non-Travel     25 - 34       Ex-Employees        R&D
# 1466       Yes  Travel_Frequently     25 - 34       Ex-Employees        R&D
# 1468       Yes      Travel_Rarely    Under 25       Ex-Employees        R&D
#
# ...
